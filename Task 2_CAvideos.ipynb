# %%
#First, import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#import the file and create a data frame
vid = pd.read_csv('CAvideos.csv')

vid.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
#HISTOGRAM
#It is good to specify the columns. It will produce histograms of each of the specified columns.

df = pd.DataFrame(vid, columns = ['category_id', 'views', 'likes', 'dislikes', 'comment_count'])
df.hist()

plt.style.use('ggplot') # make graphs in the style of R's ggplot

#show plots
plt.show()

# %%
#Interpretation
# The y-axis represents the count of the feature. The x-axis is a range, from initial point of the bar to the end of the bar
# In category id, the category of the id fall mainly between 22 and 25. None is more than 30 and there are some in lower ranges.

# %%
BAR CHARTS
#Bar chart presents categorical data in a way that bar lenght or are corresponds to the values of the data

# %%
#Plotting bar charts
import numpy as np
import matplotlib.pyplot as plt
views = vid.views
cat_id = vid.category_id
likes = vid.likes
dislikes = vid.dislikes
#objects = ("category_id", "comments_count", "dislikes", "likes", "views")

#x_pos = np.arange(len(objects)
df.describe()
#plt.bar(views, cat_id, align='center')
#plt.bar(df['views'], df['cat_id'], df['likes'])
#plt.show()

#plt.plot.bar()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %%
#BOX PLOTS
df.plot.box()

# %%
# to show box plot of only one attribute
plt.boxplot(df['comment_count'])
plt.show()

# %%
# to show selected box plots on the same chart
data_to_plot = [df['likes'], df['dislikes'], df['comment_count'], df['category_id']]

#Create a fig instance
fig = plt.figure(1, figsize=(9, 6))

#Create axes instance
ax = fig.add_subplot(111)

#Create the boxplot
bp = ax.boxplot(data_to_plot)

#Custom x-axis labels
ax.set_xticklabels(['likes', 'dislikes', 'comment_count', 'category_id'])

# If you want to save it in the directory
#fig.savefig('fig1.png', bbox_inches='tight')
# Out:
# [Text(0, 0, 'likes'),
#  Text(0, 0, 'dislikes'),
#  Text(0, 0, 'comment_count'),
#  Text(0, 0, 'category_id')]

# %%
#SCATTER PLOTS
plt.scatter(df['comment_count'], df['dislikes'])
plt.xlabel('no of comment')
plt.ylabel('no of dislikes')
plt.show()

#scatter plot between dislike and category id
plt.scatter(df['category_id'], df['dislikes'])
plt.xlabel('category')
plt.ylabel('no of dislikes')
plt.show()

#scatter plot between dislike and views
plt.scatter(df['views'], df['dislikes'])
plt.xlabel('no of views')
plt.ylabel('no of dislikes')
plt.show()

#scatter plot between like and views
plt.scatter(df['views'], df['likes'])
plt.xlabel('no of views')
plt.ylabel('no of likes')
plt.show()

#scatter plot between like and category id
plt.scatter(df['category_id'], df['likes'])
plt.xlabel('category')
plt.ylabel('no of likes')
plt.show()

#scatter plot between like and comment
plt.scatter(df['likes'], df['comment_count'])
plt.xlabel('no of likes')
plt.ylabel('no of comments')
plt.show()
